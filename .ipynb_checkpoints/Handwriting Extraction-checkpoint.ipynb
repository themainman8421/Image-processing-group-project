# %% [markdown]
# # Handwriting Extraction
#
# ## Group members
# - Conor Rogers C16347693
# - James Behan C17348016
# - Monika Adamczewska C16478646
#
# # Description
#
# # Method
#
# # Testing
#
# # Conclusion
#
# # References

# %% [markdown]
# Imports

# %%
import cv2 # The OpenCV library; install using `pip install opencv-contrib-python`
import numpy as np # Helpful when working with arrays; install using `pip install numpy`
from matplotlib import pyplot as plt # Good for graphing; install using `pip install matplotlib`
from matplotlib import image as image
import easygui # An easy-to-use file-picker; pip install easygui
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-99c47d2efffe> in <module>
#       1 import cv2 # The OpenCV library; install using `pip install opencv-contrib-python`
#       2 import numpy as np # Helpful when working with arrays; install using `pip install numpy`
# ----> 3 from matplotlib import pyplot as plt # Good for graphing; install using `pip install matplotlib`
#       4 from matplotlib import image as image
#       5 import easygui # An easy-to-use file-picker; pip install easygui
#
# c:\users\jcbch\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\__init__.py in <module>
#     105 # cbook must import matplotlib only within function
#     106 # definitions, so it is safe to import from it here.
# --> 107 from . import cbook, rcsetup
#     108 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
# ...

# %% [markdown]
# Selecting an image

# %%
f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
I = cv2.imread(f)
Original = I.copy()

# %% [markdown]
# Checking an image as been selected

# %%
if I is None:
    print('Invalid input')
    sys.exit(0)

# %%
original = I.copy()

# %%
G = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

# %%
plt.title('Original Image')
plt.imshow(G, cmap = "gray") 
plt.show()

# %%
B =cv2.adaptiveThreshold(G, maxValue= 255,adaptiveMethod= cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 23,C = 10)

# %%
plt.title('Original Image')
plt.imshow(B, cmap = "gray") 
plt.show()

# %%
cv2.imshow("image", B)
key = cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Trying Colour Spaces

# %%
scale_percent = 20 # percent of original size
width = int(I.shape[1] * scale_percent / 100)
height = int(I.shape[0] * scale_percent / 100)
dim = (width, height)
img = cv2.resize(I, dim, interpolation = cv2.INTER_AREA)

# %%
#-----------------BGR-----------------
I_b=img[:,:,0]
I_g=img[:,:,1]
I_r=img[:,:,2]
comparison=np.concatenate((I_b,I_g,I_r),axis=1)
cv2.imshow("B    G   R",comparison)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
I_HSV=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
I_h=I_HSV[:,:,0]
I_s=I_HSV[:,:,1]
I_v=I_HSV[:,:,2]
comparison=np.concatenate((I_h,I_s,I_v),axis=1)
comparison2 = comparison
# cv2.imwrite(r'C:\Users\conor\Desktop\College_4\Image\Project\HSV_LandBlue.jpg',comparison)
cv2.imshow("B    G   R",comparison)
cv2.imshow("H",I_h)
cv2.imshow("S",I_s)
cv2.imshow("V",I_v)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
Text = I_s - G
cv2.imshow("Text", Text)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
Final = Text - G
cv2.imshow("Final", Final)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#  ----------------YUV-----------
I_YUV=cv2.cvtColor(img,cv2.COLOR_BGR2YUV)
I_y=I_YUV[:,:,0]
I_u=I_YUV[:,:,1]
I_v=I_YUV[:,:,2]
comparison=np.concatenate((I_y,I_u,I_v),axis=1)

cv2.imshow("Y    U   V",comparison)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#  ----------------YCrCb-----------
I_ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)
I_y=I_ycrcb[:,:,0]
I_cr=I_ycrcb[:,:,1]
I_cb=I_ycrcb[:,:,2]
comparison=np.concatenate((I_y,I_cr,I_cb),axis=1)

cv2.imshow("Y    Cr   Cb",comparison)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#  ----------------XYZ-----------
I_XYZ=cv2.cvtColor(img,cv2.COLOR_BGR2XYZ)
I_x=I_XYZ[:,:,0]
I_y=I_XYZ[:,:,1]
I_z=I_XYZ[:,:,2]
comparison=np.concatenate((I_x,I_y,I_z),axis=1)

cv2.imshow("X    Y   Z",comparison)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#  ----------------LAB-----------
I_LAB=cv2.cvtColor(img,cv2.COLOR_BGR2LAB)
I_l=I_LAB[:,:,0]
I_a=I_LAB[:,:,1]
I_b=I_LAB[:,:,2]
comparison=np.concatenate((I_l,I_a,I_b),axis=1)

cv2.imshow("L    A   B",comparison)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Contrast

# %%
#--------------------- BGR --------------------
Hb = cv2.equalizeHist(I_b)
Hg = cv2.equalizeHist(I_g)
Hr = cv2.equalizeHist(I_r)
equBGR=img
equBGR[:,:,0]=Hb
equBGR[:,:,1]=Hg
equBGR[:,:,2]=Hr
cv2.imshow("original",original)
key=cv2.waitKey(0)
cv2.imshow("Equalised Blue",Hb)
key=cv2.waitKey(0)
cv2.imshow("Equalised Green",Hg)
key=cv2.waitKey(0)
cv2.imshow("Equalised Red",Hr)
key=cv2.waitKey(0)
cv2.imshow("Equalised All",equBGR)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#--------------------- HSV --------------------
Hh = cv2.equalizeHist(I_h)
Hs = cv2.equalizeHist(I_s)
Hv = cv2.equalizeHist(I_v)
equHSV=I_HSV
equHSV[:,:,0]=Hh
equHSV[:,:,1]=Hs
equHSV[:,:,2]=Hv
equHSV= cv2.cvtColor(equHSV,cv2.COLOR_HSV2BGR)
equHSV1=cv2.cvtColor(equHSV,cv2.COLOR_BGR2GRAY)
cv2.imshow("original",original)
key=cv2.waitKey(0)
cv2.imshow("Equalised Hue",Hh)
key=cv2.waitKey(0)
cv2.imshow("Equalised Sat",Hs)
key=cv2.waitKey(0)
cv2.imshow("Equalised Value",Hv)
key=cv2.waitKey(0)
cv2.imshow("Equalised All",equHSV)
key=cv2.waitKey(0)
cv2.imshow("Equalised All in gray",equHSV1)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # ------------------Histograms-------------------------

# %%
#-------------HSV--------------------
Values= I_h.ravel()
plt.hist(Values,bins=256,range=[0,256])
H = cv2.equalizeHist(G)
Lum_Values=I_lum.ravel()
plt.hist(Lum_Values,bins=256,range=[0,256])

# %%
#--------------BGR-----------------------
plt.figure(1)
Blue= I_b.ravel()
plt.hist(Blue,bins=256,range=[0,256])
plt.title('Blue')
plt.show()
plt.figure(2)
Green=I_g.ravel()
plt.hist(Green,bins=256,range=[0,256])
plt.title('Green')
plt.show()
plt.figure(3)
Red=I_r.ravel()
plt.hist(Red,bins=256,range=[0,256])
plt.title('Red')
plt.show()

# %% [markdown]
# more random stuff

# %%
RangeLower = (0, 0, 100)
RangeUpper = (42, 80, 255)
B = cv2.inRange(I, RangeLower, RangeUpper)

# %%
cv2.imshow("Equalised All in gray",B)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
HSV = cv2.cvtColor(I,cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(HSV)


#plt.title("S")
#plt.imshow(s,cmap="gray")
#plt.show()

#Performing thresholding on the saturation values of the image
T = np.mean(s) + np.std(s)
T,B = cv2.threshold(s,thresh=T+20,maxval=255,type = cv2.THRESH_BINARY)

#plt.title("B")
#plt.imshow(B,cmap="gray")
#plt.show()

E = cv2.Canny(B,threshold1=1, threshold2=2)
#Ix = cv2.Sobel(B,ddepth = cv2.CV_64F,dx=1,dy=0)
#Iy = cv2.Sobel(B,ddepth = cv2.CV_64F,dx=0,dy=1)

plt.title("E")
plt.imshow(E,cmap="gray")
plt.show()

cv2.imshow("Equalised All in gray",E)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

#plt.title("Iy")
#plt.imshow(Iy,cmap="gray")
#plt.show()

# %% [markdown]
# Monicas

# %%
HSV = cv2.cvtColor(I,cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(HSV)

YUV = cv2.cvtColor(I,cv2.COLOR_BGR2YUV)
y,u,v = cv2.split(YUV)

YCrCb = cv2.cvtColor(I,cv2.COLOR_BGR2YCrCb)
y,cr,cb = cv2.split(YCrCb)


#plt.title("S")
#plt.imshow(s,cmap="gray")
#plt.show()

#Performing thresholding on the saturation values of the image
T = np.mean(s) + np.std(s)
#T,B = cv2.threshold(s,thresh=10,maxval=255,type = cv2.THRESH_BINARY) ## FINDS THE LINES IN THE PAGE
T,B = cv2.threshold(s,thresh=10,maxval=255,type = cv2.THRESH_BINARY)

ROI = cv2.bitwise_and(s,s,mask=B)


plt.title("B")
plt.imshow(B,cmap="gray")
plt.show()

E = cv2.Canny(B,threshold1=0, threshold2=255)

plt.title("E")
plt.imshow(E,cmap="gray")
plt.show()

# cv2.imshow(" y",y)
# cv2.imshow(" u",u)
# cv2.imshow(" v",v)

# cv2.imshow(" h",h)
# cv2.imshow(" s",s)
# cv2.imshow(" v",v)

# cv2.imshow(" y",y)
# cv2.imshow(" cr",cr)
# cv2.imshow(" cb",cb)


# cv2.imshow(" G",G)
# cv2.imshow(" ROI",ROI)
# cv2.imshow(" All in gray",B)
# cv2.imshow("Equalised All in gray",E)

#Ix = cv2.Sobel(E,ddepth = cv2.CV_64F,dx=1,dy=0)
#Iy = cv2.Sobel(E,ddepth = cv2.CV_64F,dx=0,dy=1)

#plt.title("IX")
#plt.imshow(Ix,cmap="gray")
#plt.show()


T,B = cv2.threshold(s,thresh=10,maxval=255,type = cv2.THRESH_BINARY)

cv2.imshow(" cb",B)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
S = s - B 
S1 = s - E

# %%
cv2.imshow("S",S)
cv2.imshow("S1",S1)
key=cv2.waitKey(0)

# %%
OI = cv2.bitwise_or(s, B)
OII = cv2.bitwise_or(s, E)

# %%
cv2.imshow("OI",OI)
cv2.imshow("OII",OII)
key=cv2.waitKey(0)

# %%
MORE = s - OI

# %%
cv2.imshow("OII",MORE)
key=cv2.waitKey(0)

# %%
import cv2 # The OpenCV library; install using `pip install opencv-contrib-python`
import numpy as np # Helpful when working with arrays; install using `pip install numpy`
from matplotlib import pyplot as plt # Good for graphing; install using `pip install matplotlib`
from matplotlib import image as image
import easygui # An easy-to-use file-picker; pip install easygui

# %%
f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
I = cv2.imread(f)
Original = I.copy()

# %%
G = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

# %%
E =cv2.Canny(I,threshold1=100,threshold2=255)

# %%
cv2.imshow("OII",E)
key=cv2.waitKey(0)

# %%
contours,_ =cv2.findContours(G, mode=cv2.RETR_EXTERNAL, method=cv2.CHAIN_APPROX_NONE)

# %%
ret, bw_img = cv2.threshold(G,140,255,cv2.THRESH_BINARY)

# %%
cv2.imshow("OII",bw_img)
key=cv2.waitKey(0)

# %%
R = B-bw_img

# %%
cv2.imshow("OII",R)
key=cv2.waitKey(0)

# %%
Q =cv2.adaptiveThreshold(R, maxValue= 200,adaptiveMethod= cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 11,C = 5)

# %%
cv2.imshow("OII",Q)
key=cv2.waitKey(0)

# %%
HSV = cv2.cvtColor(I,cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(HSV)

T = np.mean(s) + np.std(s)
T,B = cv2.threshold(s,thresh=10,maxval=255,type = cv2.THRESH_BINARY)

ROI = cv2.bitwise_and(s,s,mask=B)


plt.title("B")
plt.imshow(B,cmap="gray")
plt.show()

E = cv2.Canny(B,threshold1=0, threshold2=255)

plt.title("E")
plt.imshow(E,cmap="gray")
plt.show()


T,B = cv2.threshold(s,thresh=10,maxval=255,type = cv2.THRESH_BINARY)

G = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

ret, bw_img = cv2.threshold(G,140,255,cv2.THRESH_BINARY)

R = B-bw_img

Q =cv2.adaptiveThreshold(R, maxValue= 255,adaptiveMethod= cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 11,C = 5)

cv2.imshow(" cb",Q)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
I = cv2.imread(f)
Original = I.copy()

# %%
import cv2
import numpy as np

# Params
maxArea = 150
minArea = 10

# Read image
# I = cv2.imread('i.jpg')

# Convert to gray
Igray = cv2.cvtColor(I,cv2.COLOR_RGB2GRAY)

# Threshold
ret, Ithresh = cv2.threshold(Igray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# Keep only small components but not to small
comp = cv2.connectedComponentsWithStats(Ithresh)

labels = comp[1]
labelStats = comp[2]
labelAreas = labelStats[:,4]

for compLabel in range(1,comp[0],1):

    if labelAreas[compLabel] > maxArea or labelAreas[compLabel] < minArea:
        labels[labels==compLabel] = 0

labels[labels>0] =  1

# Do dilation
se = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(25,25))
IdilateText = cv2.morphologyEx(labels.astype(np.uint8),cv2.MORPH_DILATE,se)

# Find connected component again
comp = cv2.connectedComponentsWithStats(IdilateText)

# Draw a rectangle around the text
labels = comp[1]
labelStats = comp[2]
#labelAreas = labelStats[:,4]

for compLabel in range(1,comp[0],1):

    cv2.rectangle(I,(labelStats[compLabel,0],labelStats[compLabel,1]),(labelStats[compLabel,0]+labelStats[compLabel,2],labelStats[compLabel,1]+labelStats[compLabel,3]),(0,0,255),2)
    
cv2.imshow(" cb",I)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
img = cv2.imread(f)
Original = I.copy()

# %%
import cv2
import numpy as np

## Read
# img = cv2.imread('handwriting.jpg')

## convert to hsv
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv, (0, 0, 0), (175, 175, 130))

## slice the black
imask = mask>0
mask_black = np.zeros_like(img, np.uint8)
mask_black[imask] = img[imask]

## save 
cv2.imshow(" cb",mask_black)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
G = cv2.cvtColor(mask_black, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow(" cb",G)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
Q =cv2.adaptiveThreshold(R, maxValue= 255,adaptiveMethod= cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 11,C = 5)

# %%
cv2.imshow(" cb",Q)
key=cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
image = cv2.imread(f)
Original = image.copy()

# %%
import cv2


gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.medianBlur(gray, 5)
thresh = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,11,8)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
dilate = cv2.dilate(thresh, kernel, iterations=6)
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    ROI = image[y:y+h, x:x+w]
    cv2.imwrite('ROI.png', ROI)
    break

cv2.imshow('thresh', thresh)
# cv2.imshow('dilate', dilate)
# cv2.imshow('ROI', ROI)
cv2.waitKey()
# Out:
# -1

# %%
G = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-275-aedbc904a04b> in <module>
# ----> 1 G = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.4.0) c:\users\appveyor\appdata\local\temp\1\pip-req-build-2y91i_7w\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function '__thiscall cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x42af3541::Set<1,-1,-1>,struct cv::impl::A0x42af3541::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
B =cv2.adaptiveThreshold(G, maxValue= 255,adaptiveMethod= cv2.ADAPTIVE_THRESH_MEAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 5,C = 5)

# %%
cv2.imshow('ROI', B)
cv2.waitKey()
# Out:
# -1

# %%
shape = cv2.getStructuringElement(cv2.MORPH_RECT,(2,2))

# %%
NewMask= cv2.dilate(thresh,shape)

# %%
cv2.imshow('ROI', NewMask)
cv2.waitKey()
# Out:
# -1

# %%
import cv2 # The OpenCV library; install using `pip install opencv-contrib-python`
import numpy as np # Helpful when working with arrays; install using `pip install numpy`
from matplotlib import pyplot as plt # Good for graphing; install using `pip install matplotlib`
from matplotlib import image as image
import easygui # An easy-to-use file-picker; pip install easygui

#f = easygui.fileopenbox(filetypes=["*.jpg","*.jpeg","*.png"])
#I = cv2.imread(f)
I = cv2.imread('Image 1.jpg')
Original = I.copy()

# Error checking to see if the image was loaded correctly
if I is None:
    print('Invalid input')
    sys.exit(0)
else:
    #Converting the image to grayscale and removing any bright light streaks 
    Gray = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)
    shape = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7,7))
    closed = cv2.morphologyEx(Gray,cv2.MORPH_CLOSE, shape, iterations=2)
    inverted_mask = cv2.bitwise_not(closed)
    new_image = Gray + inverted_mask

    mask = cv2.bitwise_not(new_image)

    #Code from: https://stackoverflow.com/questions/41406547/how-to-detect-a-full-black-color-image-in-opencv-python/41414865
    #Checking if the mask has returned any part of the image.
    #If no text was found, an error message is displayed
    if cv2.countNonZero(mask) == 0:
        print ("Could not find handwritten text in image")
        sys.exit(0)
    else:
        #Applying morphology to the mask
        shape = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(4,8))
        new_mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE,shape)   
        
        #Using thresholding and morphology to filter out the horizontal lines
        T,horizontal_lines = cv2.threshold(new_mask,thresh=10,maxval=255,type = cv2.THRESH_BINARY)
        shape = cv2.getStructuringElement(cv2.MORPH_RECT,(160,1))
        horizontal_lines = cv2.morphologyEx(horizontal_lines, cv2.MORPH_OPEN,shape)
        
        #Using thresholding and morphology to filter out the vertical lines
        T,vertical_lines = cv2.threshold(new_mask,thresh=10,maxval=255,type = cv2.THRESH_BINARY)
        shape = cv2.getStructuringElement(cv2.MORPH_RECT,(1,160))
        vertical_lines = cv2.morphologyEx(vertical_lines, cv2.MORPH_OPEN,shape)
        
        #Creating a combined mask for the vertical and horizontal lines
        Lines = vertical_lines + horizontal_lines
        Inverted_Lines = cv2.bitwise_not(Lines)
        
        #Removing the lines from the original mask to get a more accurate mask of the handwritten text
        ROI = cv2.bitwise_and(mask, mask, mask = Inverted_Lines)

        #Applying thresholding and morphology to filter out the text from the image
        T,Text = cv2.threshold(ROI, thresh = 50, maxval = 255, type = cv2.THRESH_BINARY)
        shape = cv2.getStructuringElement(cv2.MORPH_RECT,(2,2))
        Text = cv2.dilate(Text,shape, iterations = 2)
        Text = cv2.cvtColor(Text, cv2.COLOR_GRAY2BGR)

        #Code from https://stackoverflow.com/questions/60937583/is-it-possible-to-paste-an-image-on-top-of-another-in-opencv
        #Creating a blank white image for the background
        white = np.full_like(I, (255,255,255))

        #Applying a mask to the original image and the blank white image
        result = np.where(Text!=0, I, white)
        
        #Converting the result image to HSV
        HSV = cv2.cvtColor(result,cv2.COLOR_BGR2HSV)
        h,s,v = cv2.split(HSV)

        #Enhancing the output image
        for y in range(v.shape[0]):
            for x in range(v.shape[1]):
                if all(v[y,x] != [255,255,255]):
                    v[y][x] = v[y][x] - 100
                    ROI1 = v
        
        B =cv2.adaptiveThreshold(ROI1, maxValue= 255,adaptiveMethod= cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                         thresholdType= cv2.THRESH_BINARY,blockSize= 23,C = 20)
        ROI1 = cv2.cvtColor(B, cv2.COLOR_GRAY2BGR)
        
        #Creating the final enhanced image
        FinalImage = cv2.bitwise_and(ROI1,result)
        
        #Displayig the original and the processed images to the user
        plt.title("Original")
        plt.imshow(Original)
        plt.show()
        
        plt.title("Final Image")
        plt.imshow(FinalImage,cmap="gray")
        plt.show()
        
        cv2.imshow('thresh', FinalImage)
        cv2.waitKey()
